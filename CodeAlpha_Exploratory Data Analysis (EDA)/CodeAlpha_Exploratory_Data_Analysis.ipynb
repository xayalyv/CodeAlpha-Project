# %%
import pandas as pd

# %%
path = "/content/new2_books_dataset_6_columns.csv"
df = pd.read_csv("/content/new2_books_dataset_6_columns.csv", encoding="latin-1")
df.head()
# Out:
#                                    Title  Price (£) Rating Availability  \
# 0                   A Light in the Attic      51.77  Three     In stock
# 1                     Tipping the Velvet      53.74    One     In stock
# 2                             Soumission      50.10    One     In stock
# 3                          Sharp Objects      47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind      54.23   Five     In stock
#
#    Stock Count Category      Category.1  Amounts  Unnamed: 8  \
# 0          0.0  Unknown         Unknown     20.0         NaN
# 1          0.0  Unknown        Thriller      3.0         NaN
# 2          0.0  Unknown           Music      1.0         NaN
# 3          0.0  Unknown  Food and Drink      1.0         NaN
# 4          0.0  Unknown         Romance      2.0         NaN
#
#    Total amount of each book
# 0                      51.77
# 1                      53.74
# 2                      50.10
# 3                      47.82
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Title                      49 non-null     object
#  1   Price (£)                  49 non-null     float64
#  2   Rating                     49 non-null     object
#  3   Availability               49 non-null     object
#  4   Stock Count                49 non-null     float64
#  5   Category                   49 non-null     object
#  6   Category.1                 16 non-null     object
#  7   Amounts                    16 non-null     float64
#  8   Unnamed: 8                 0 non-null      float64
#  9   Total amount of each book  49 non-null     float64
# dtypes: float64(5), object(5)
# memory usage: 31.4+ KB
#        Price (£)  Stock Count    Amounts  Unnamed: 8  \
# count  49.000000    49.000000  16.000000         0.0
# ...

# %%
rating_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}

df["Rating Numeric"] = df["Rating"].map(rating_map)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.hist(df["Price (£)"], bins=30)
plt.title("Distribution of Book Prices")
plt.xlabel("Price (£)")
plt.ylabel("Frequency")
plt.show()

# %%
avg_price_by_rating = df.groupby("Rating Numeric")["Price (£)"].mean()

plt.figure()
avg_price_by_rating.plot(kind="bar")
plt.title("Average Book Price by Rating")
plt.xlabel("Rating")
plt.ylabel("Average Price (£)")
plt.show()

# %%
plt.figure()
df["Category"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Book Categories")
plt.xlabel("Category")
plt.ylabel("Number of Books")
plt.show()

# %%
plt.figure()
plt.hist(df["Stock Count"], bins=30)
plt.title("Distribution of Stock Counts")
plt.xlabel("Stock Count")
plt.ylabel("Frequency")
plt.show()

# %%
# Books marked in stock but having zero quantity
df[(df["Stock Count"] == 0) & (df["Availability"].str.contains("In stock"))]
# Out:
#                                                 Title  Price (£) Rating  \
# 0                                A Light in the Attic      51.77  Three
# 1                                  Tipping the Velvet      53.74    One
# 2                                          Soumission      50.10    One
# 3                                       Sharp Objects      47.82   Four
# 4               Sapiens: A Brief History of Humankind      54.23   Five
# 5                                     The Requiem Red      22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...      33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...      17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...      22.60   Four
# 9                                     The Black Maria      52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)      13.99    Two
# 11                              Shakespeare's Sonnets      20.66   Four
# ...

# %%
#summary
print("Total books:", len(df))
print("Average price:", df["Price (£)"].mean())
print("Most common category:", df["Category"].mode()[0])
print("Average stock count:", df["Stock Count"].mean())
# Out:
# Total books: 400
# Average price: 35.4765306122449
# Most common category: Unknown
# Average stock count: 10.510204081632653
